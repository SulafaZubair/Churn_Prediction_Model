# %% [markdown]
# LOADING DATASET
# CONVERTING INTO DATAFRAME
# AND VERIFYING IT

# %%
import pandas as pd

# %%
data= pd.read_csv("Data//Foodpanda Analysis Dataset - Foodpanda Analysis Dataset.csv")

# %%
data
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 1          C2831    Male     Adult     Multan    7/7/2024    O6831  8/23/2023
# 2          C2851   Other    Senior     Multan   6/20/2025    O6851  8/23/2023
# 3          C1694  Female    Senior   Peshawar    9/5/2023    O5694  8/23/2023
# 4          C4339   Other    Senior     Lahore  12/29/2023    O8339  8/24/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
# ...

# %%
df_data=pd.DataFrame(data)

# %%
df_data
# Out:
#      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 1          C2831    Male     Adult     Multan    7/7/2024    O6831  8/23/2023
# 2          C2851   Other    Senior     Multan   6/20/2025    O6851  8/23/2023
# 3          C1694  Female    Senior   Peshawar    9/5/2023    O5694  8/23/2023
# 4          C4339   Other    Senior     Lahore  12/29/2023    O8339  8/24/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df_data.shape
# Out:
# (6000, 20)

# %% [markdown]
# Difference between .info (without parentheses) and .info( with parentheses)
#
# This refers to the method itself, it does not execute it.
#
# You get a method object, not the information you want.
#
# .info() (with parentheses)
#
# This calls the method, actually runs it, and prints the summary.

# %%
data.info
# Out:
# <bound method DataFrame.info of      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 1          C2831    Male     Adult     Multan    7/7/2024    O6831  8/23/2023
# 2          C2851   Other    Senior     Multan   6/20/2025    O6851  8/23/2023
# 3          C1694  Female    Senior   Peshawar    9/5/2023    O5694  8/23/2023
# 4          C4339   Other    Senior     Lahore  12/29/2023    O8339  8/24/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      customer_id  gender       age       city signup_date order_id order_date  \
# 0          C5663    Male     Adult   Peshawar   1/14/2024    O9663  8/23/2023
# 1          C2831    Male     Adult     Multan    7/7/2024    O6831  8/23/2023
# 2          C2851   Other    Senior     Multan   6/20/2025    O6851  8/23/2023
# 3          C1694  Female    Senior   Peshawar    9/5/2023    O5694  8/23/2023
# 4          C4339   Other    Senior     Lahore  12/29/2023    O8339  8/24/2023
# ...          ...     ...       ...        ...         ...      ...        ...
# 5995       C6849    Male     Adult     Multan  11/25/2024   O10849  8/22/2025
# 5996       C3787  Female     Adult  Islamabad   1/28/2025    O7787  8/22/2025
# 5997       C2841   Other  Teenager  Islamabad  10/19/2023    O6841  8/22/2025
# 5998       C1624    Male     Adult  Islamabad   6/17/2024    O5624  8/22/2025
# 5999       C2068  Female     Adult     Multan   3/15/2025    O6068  8/22/2025
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      6000 non-null   object
#  1   gender           6000 non-null   object
#  2   age              6000 non-null   object
#  3   city             6000 non-null   object
#  4   signup_date      6000 non-null   object
#  5   order_id         6000 non-null   object
#  6   order_date       6000 non-null   object
#  7   restaurant_name  6000 non-null   object
#  8   dish_name        6000 non-null   object
#  9   category         6000 non-null   object
#  10  quantity         6000 non-null   int64
#  11  price            6000 non-null   float64
#  12  payment_method   6000 non-null   object
#  13  order_frequency  6000 non-null   int64
#  14  last_order_date  6000 non-null   object
#  15  loyalty_points   6000 non-null   int64
# ...

# %% [markdown]
# This shows that there are 20 columns and all have non-null values, whereas, rating column has 1968 missing values.

# %%
data.describe()
# Out:
#           quantity        price  order_frequency  loyalty_points       rating
# count  6000.000000  6000.000000      6000.000000     6000.000000  4032.000000
# mean      2.991667   800.524880        25.304667      250.173667     3.012153
# std       1.414778   404.855029        14.358930      144.608478     1.411615
# min       1.000000   100.300000         1.000000        0.000000     1.000000
# 25%       2.000000   441.997500        13.000000      125.000000     2.000000
# 50%       3.000000   806.460000        25.000000      249.500000     3.000000
# 75%       4.000000  1149.737500        37.000000      378.000000     4.000000
# max       5.000000  1499.950000        50.000000      500.000000     5.000000

# %%
data.describe(include='all')
# Out:
#        customer_id  gender       age    city signup_date order_id order_date  \
# count         6000    6000      6000    6000        6000     6000       6000
# unique        6000       3         3       5         730     6000        730
# top          C5663  Female  Teenager  Multan  10/18/2023    O9663   9/8/2024
# freq             1    2018      2062    1256          18        1         20
# mean           NaN     NaN       NaN     NaN         NaN      NaN        NaN
# std            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# min            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 25%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 50%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 75%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# max            NaN     NaN       NaN     NaN         NaN      NaN        NaN
#
# ...

# %%
data.describe(include=['object'])
# Out:
#        customer_id  gender       age    city signup_date order_id order_date  \
# count         6000    6000      6000    6000        6000     6000       6000
# unique        6000       3         3       5         730     6000        730
# top          C5663  Female  Teenager  Multan  10/18/2023    O9663   9/8/2024
# freq             1    2018      2062    1256          18        1         20
#
#        restaurant_name dish_name category payment_method last_order_date  \
# count             6000      6000     6000           6000            6000
# unique               5         5        5              3             366
# top             Subway     Pasta  Italian           Cash       8/13/2025
# freq              1260      1262     1236           2039              28
#
#        churned rating_date delivery_status
# count     6000        6000            6000
# unique       2         366               3
# top     Active   6/14/2025       Delivered
# ...

# %%
data['gender'].value_counts()
# Out:
# gender
# Female    2018
# Male      2017
# Other     1965
# Name: count, dtype: int64

# %%
data['age'].unique()
# Out:
# array(['Adult', 'Senior', 'Teenager'], dtype=object)

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Other', 'Female'], dtype=object)

# %%
data['age'].value_counts()
# Out:
# age
# Teenager    2062
# Adult       1984
# Senior      1954
# Name: count, dtype: int64

# %%
data['city'].value_counts()
# Out:
# city
# Multan       1256
# Lahore       1217
# Peshawar     1195
# Islamabad    1187
# Karachi      1145
# Name: count, dtype: int64

# %%
data.groupby('churned')['gender'].value_counts()
# Out:
# churned   gender
# Active    Female    1027
#           Male      1009
#           Other      980
# Inactive  Male      1008
#           Female     991
#           Other      985
# Name: count, dtype: int64

# %%
data.groupby('churned')['age'].value_counts()
# Out:
# churned   age
# Active    Teenager    1046
#           Adult       1021
#           Senior       949
# Inactive  Teenager    1016
#           Senior      1005
#           Adult        963
# Name: count, dtype: int64

# %%
data.groupby('churned')['city'].value_counts()
# Out:
# churned   city
# Active    Peshawar     623
#           Multan       608
#           Islamabad    602
#           Karachi      597
#           Lahore       586
# Inactive  Multan       648
#           Lahore       631
#           Islamabad    585
#           Peshawar     572
#           Karachi      548
# Name: count, dtype: int64

# %%
data.groupby('age')['gender'].value_counts()
# Out:
# age       gender
# Adult     Male      675
#           Female    667
#           Other     642
# Senior    Female    669
#           Male      647
#           Other     638
# Teenager  Male      695
#           Other     685
#           Female    682
# Name: count, dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5995    False
# 5996    False
# 5997    False
# 5998    False
# 5999    False
# Length: 6000, dtype: bool

# %%
data.groupby('churned')['delivery_status'].value_counts()
# Out:
# churned   delivery_status
# Active    Delivered          1042
#           Cancelled           996
#           Delayed             978
# Inactive  Delivered          1018
#           Delayed             994
#           Cancelled           972
# Name: count, dtype: int64

# %%
data.groupby(['gender','age','delivery_status'])['churned'].value_counts()
# Out:
# gender  age       delivery_status  churned
# Female  Adult     Cancelled        Active      117
#                                    Inactive    103
#                   Delayed          Active      134
#                                    Inactive    109
#                   Delivered        Inactive    105
#                                    Active       99
#         Senior    Cancelled        Inactive    109
#                                    Active      103
#                   Delayed          Inactive    119
#                                    Active       91
#                   Delivered        Active      126
#                                    Inactive    121
#         Teenager  Cancelled        Active      117
#                                    Inactive    102
#                   Delayed          Active      117
#                                    Inactive    100
#                   Delivered        Active      123
#                                    Inactive    123
# ...

# %%
data.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='object')

# %%
for col in data.columns:
    print(f"{col}: {data[col].nunique()} unique values")
# Out:
# customer_id: 6000 unique values
# gender: 3 unique values
# age: 3 unique values
# city: 5 unique values
# signup_date: 730 unique values
# order_id: 6000 unique values
# order_date: 730 unique values
# restaurant_name: 5 unique values
# dish_name: 5 unique values
# category: 5 unique values
# quantity: 5 unique values
# price: 5872 unique values
# payment_method: 3 unique values
# order_frequency: 50 unique values
# last_order_date: 366 unique values
# loyalty_points: 501 unique values
# churned: 2 unique values
# rating: 5 unique values
# rating_date: 366 unique values
# delivery_status: 3 unique values

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Churned'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ...
